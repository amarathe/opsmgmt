# %% [markdown]
# ## Operations Management - Project Management Homework
# ### Ashwin Marathe
#
# Code including calculation and placement algorithm located here: https://github.com/amarathe/opsmgmt

# %%
from network import GraphVisualization

# %% [markdown]
# ### Q1.

# %%
G = GraphVisualization()
G.populate_edges([
    ("B", "C"),
    ("A", "D"),
    ("B", "E"),
    ("B", "F"),
    ("D", "G"),
    ("E", "G"),
    ("F", "H"),
    ])
G.visualize()

# %% [markdown]
# ### Q2

# %%
G = GraphVisualization()
G.populate_edges([
    ("A", "C"),
    ("B", "C"),
    ("B", "D"),
    ("B", "E"),
    ("C", "F"),
    ("D", "F"),
    ("E", "F"),
    ("E", "G")
    ])
G.visualize()

# %% [markdown]
# Note: B should point to C. I have no idea why C points to B in the graph (it is not a bug in my code as far as I can tell!)

# %% [markdown]
# ### Q4.

# %%
G = GraphVisualization()
G.populate_edges([
    ("A", "C"),
    ("A", "D"),
    ("B", "E"),
    ("B", "F"),
    ("C", "G"),
    ("E", "H"),
    ("D", "H"),
    ])
G.populate_weights({
    "A": 3,
    "B": 4,
    "C": 5,
    "D": 3,
    "E": 2,
    "F": 3,
    "G": 7,
    "H": 5
    })
G.populate_timings()
G.visualize()

# %% [markdown]
# ### Q5.

# %%
G = GraphVisualization()
G.populate_edges([
    ("A", "D"),
    ("B", "E"),
    ("C", "F"),
    ("C", "G"),
    ("E", "H"),
    ("D", "H"),
    ("H", "I"),
    ("F", "I"),
    ("G", "J"),
    ])
G.populate_weights({
    "A": 4,
    "B": 3,
    "C": 3,
    "D": 5,
    "E": 4,
    "F": 7,
    "G": 6,
    "H": 3,
    "I": 4,
    "J": 6
    })
G.populate_timings()
G.visualize()

# %% [markdown]
# Critical paths are C->G->J and A->D->H->I

# %% [markdown]
# ### Q6.

# %%
G = GraphVisualization()
G.populate_edges([
    ("A", "B"),
    ("A", "C"),
    ("B", "D"),
    ("C", "E"),
    ("C", "F"),
    ("D", "G"),
    ("E", "G"),
    ("F", "H"),
    ("F", "I"),
    ("G", "J"),
    ("H", "J"),
    ("H", "K"),
    ("G", "K"),
    ("I", "L"),
    ("K", "L"),
    ])
G.populate_weights({
    "A": 3,
    "B": 7,
    "C": 6,
    "D": 6,
    "E": 2,
    "F": 5,
    "G": 5,
    "H": 3,
    "I": 8,
    "J": 7,
    "K": 7,
    "L": 5
    })
G.populate_timings()
G.visualize()

# %% [markdown]
# Critical paths are A->B->D->G->K->L and A->B->D->G->J

# %% [markdown]
# ### Q7.

# %%
G = GraphVisualization()
G.populate_edges([
    ("A", "B"),
    ("A", "D"),
    ("A", "E"),
    ("A", "F"),
    ("B", "C"),
    ("C", "G"),
    ("E", "G"),
    ("G", "H"),
    ("H", "I"),
    ("D", "K"),
    ("G", "K"),
    ("G", "L"),
    ])
G.populate_weights({
    "A": 4,
    "B": 2,
    "C": 3,
    "D": 3,
    "E": 2,
    "F": 2,
    "G": 1.5,
    "H": 1,
    "I": 1.5,
    "K": 3,
    "L": 2
    })
G.populate_timings()
G.visualize()

# %% [markdown]
# Critical path is A->B->C->G->H->I
